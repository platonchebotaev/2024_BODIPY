# %%
#после того, как прогнали генетический алгоритм, выделили все названия колонок, вставляем сюда и все собирается в 1 файл
import pandas as pd 
import numpy as np
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from IPython.display import SVG
from IPython.display import display

# %%
data = pd.read_excel('C://Users//plato//Documents//BDP//Toluene//LnFl_LnO2//Toluene_ready_17_04.xlsx', index_col=0)

# %%
data
# Out:
#       nHet     Mi    PJI2     Fsp3     BLI  piPC05   IVDE    AAC  VE1_X  \
# SrNo
# 1        5  1.136  1.0000  0.00000  0.8175   5.323  1.689  1.908  3.256
# 2        5  1.137  0.7500  0.30770  0.9046   5.698  1.711  1.690  3.703
# 21       5  1.118  0.8000  0.17390  0.8929   6.542  1.698  1.527  3.907
# 26       7  1.119  0.8000  0.16670  0.8674   6.644  1.686  1.695  4.182
# 27       5  1.112  0.8000  0.14810  0.8867   6.859  1.660  1.483  4.352
# 28       5  1.108  1.0000  0.12120  0.8877   7.062  1.613  1.425  4.900
# 29       5  1.108  1.0000  0.12120  0.8877   7.017  1.613  1.425  4.290
# 30       5  1.108  0.8750  0.12120  0.8868   6.955  1.613  1.425  4.148
# 31       5  1.109  0.8333  0.13790  0.8760   7.073  1.630  1.466  4.472
# 32       5  1.097  1.0000  0.00000  0.8360   7.214  1.417  1.469  4.781
# 33       5  1.105  1.0000  0.12120  0.8731   7.292  1.599  1.429  4.843
# 37       7  1.114  1.0000  0.12900  0.8897   6.654  1.430  1.585  4.482
# ...

# %%
merged_df = data[['ATSC4e', 'nTB:(Dragon7)', 'CATS2D_04_PL', 'F10[C-N]', 'IVDE', 'Eig03_EA(dm)', 'TDB01e', 'LnLn']]

# %%
merged_df
# Out:
#       ATSC4e  nTB:(Dragon7)  CATS2D_04_PL  F10[C-N]   IVDE  Eig03_EA(dm)  \
# SrNo
# 1     0.4766              0             2         0  1.689        0.0000
# 2     0.2636              0             3         0  1.711        0.0000
# 21    0.2131              0             5         0  1.698        0.0000
# 26    0.3993              0             5         0  1.686        0.0000
# 27    0.2332              0             5         0  1.660        0.0000
# 28    0.2635              0             5         2  1.613        0.0000
# 29    0.2519              0             7         0  1.613        0.0000
# 30    0.2564              0             7         3  1.613        0.0000
# 31    0.2284              0             5         0  1.630        0.0000
# 32    0.2012              0             4         4  1.417        0.0000
# 33    0.2421              0             5         4  1.599        0.0000
# 37    0.3406              0             6         9  1.430        0.6000
# ...

# %%
merged_df
# Out:
#       ATSC4e  nTB:(Dragon7)  CATS2D_04_PL  F10[C-N]   IVDE  Eig03_EA(dm)  \
# SrNo
# 1     0.4766              0             2         0  1.689        0.0000
# 2     0.2636              0             3         0  1.711        0.0000
# 21    0.2131              0             5         0  1.698        0.0000
# 26    0.3993              0             5         0  1.686        0.0000
# 27    0.2332              0             5         0  1.660        0.0000
# 28    0.2635              0             5         2  1.613        0.0000
# 29    0.2519              0             7         0  1.613        0.0000
# 30    0.2564              0             7         3  1.613        0.0000
# 31    0.2284              0             5         0  1.630        0.0000
# 32    0.2012              0             4         4  1.417        0.0000
# 33    0.2421              0             5         4  1.599        0.0000
# 37    0.3406              0             6         9  1.430        0.6000
# ...

# %%
merged_df.to_excel(f'Toluene_ready_LnLn_17_04.xlsx', index=True)
